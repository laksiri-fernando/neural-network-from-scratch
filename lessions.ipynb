# %% [markdown]
# # Important Lesions

# %% [markdown]
# ## Function Which Returns a Function

# %%
def add_n(n):
    def add_to_vector(v):
        return [element + n for element in v]
    return add_to_vector

c = add_n(10)([1, 5, 3])

print(c)
# Out:
# [11, 15, 13]

# %% [markdown]
# ## Create an Array of Zeros

# %%
import numpy as np

print(np.zeros((2,2,2)))  # Output: [[0. 0.] [0. 0.] [0. 0.]]
# Out:
# [[[0. 0.]
#   [0. 0.]]
#
#  [[0. 0.]
#   [0. 0.]]]
